# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np

# %%
img_size = 64
batch_size = 32

datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2   # 20% for validation
)

train_data = datagen.flow_from_directory(
    "images of DC",                 # root folder with cats/ & dogs/
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode="binary",
    subset="training",
    shuffle=True
)

val_data = datagen.flow_from_directory(
    "images of DC",
    target_size=(img_size, img_size),
    batch_size=batch_size,
    class_mode="binary",
    subset="validation",
    shuffle=True
)
# Out:
# Found 801 images belonging to 2 classes.
# Found 200 images belonging to 2 classes.

# %%
model = Sequential([
    Flatten(input_shape=(img_size, img_size, 3)),  # flatten images
    Dense(512, activation="relu"),
    Dropout(0.3),
    Dense(256, activation="relu"),
    Dropout(0.3),
    Dense(1, activation="sigmoid")  # binary output
])

# %%
model.compile(optimizer="adam",
              loss="binary_crossentropy",
              metrics=["accuracy"])

# %%
history = model.fit(
    train_data,
    epochs=10,
    validation_data=val_data
)
# Out:
# Epoch 1/10
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 7s 132ms/step - accuracy: 0.4906 - loss: 2.9412 - val_accuracy: 0.5300 - val_loss: 0.6977
# Epoch 2/10
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.5406 - loss: 1.0200 - val_accuracy: 0.4950 - val_loss: 0.7461
# Epoch 3/10
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 103ms/step - accuracy: 0.5231 - loss: 0.8972 - val_accuracy: 0.4800 - val_loss: 0.7197
# Epoch 4/10
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.5343 - loss: 0.8215 - val_accuracy: 0.4850 - val_loss: 0.7035
# Epoch 5/10
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.5169 - loss: 0.7158 - val_accuracy: 0.5000 - val_loss: 0.7029
# Epoch 6/10
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.5556 - loss: 0.6931 - val_accuracy: 0.5200 - val_loss: 0.6971
# Epoch 7/10
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.5331 - loss: 0.6823 - val_accuracy: 0.4950 - val_loss: 0.7016
# Epoch 8/10
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.5518 - loss: 0.6877 - val_accuracy: 0.4950 - val_loss: 0.7008
# Epoch 9/10
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.5481 - loss: 0.6799 - val_accuracy: 0.5000 - val_loss: 0.7011
# Epoch 10/10
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.5144 - loss: 0.6970 - val_accuracy: 0.5000 - val_loss: 0.6937

# %%
loss, acc = model.evaluate(val_data)
print("Validation Accuracy:", acc)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5150 - loss: 0.7010
# Validation Accuracy: 0.5149999856948853

# %%
from tensorflow.keras.preprocessing import image

img_path =img_path = "C:\\Users\\COMP\\Documents\\deep learning (projects)\\lion-3576045_1280 (1).jpg"
img = image.load_img(img_path, target_size=(img_size, img_size))
img_array = image.img_to_array(img) / 255.0
img_array = np.expand_dims(img_array, axis=0)

prediction = model.predict(img_array)

if prediction[0][0] > 0.5:
    print("Predicted: Dog 🐶")
else:
    print("Predicted: Cat 🐱")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# Predicted: Dog 🐶
