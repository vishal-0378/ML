# %%
#importing the Libraies
import numpy as np
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('/content/Social_Network_Ads.csv')

# %%
dataset.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
dataset.tail()
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0            1
# 1    15810944   35            20000          0            1
# 2    15668575   26            43000          0            0
# 3    15603246   27            57000          0            0
# 4    15804002   19            76000          0            1
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1            0
# 396  15706071   51            23000          1            1
# 397  15654296   50            20000          1            0
# 398  15755018   36            33000          0            1
# 399  15594041   49            36000          1            0
#
# [400 rows x 5 columns]

# %%
X=dataset[['Age', 'EstimatedSalary','Gender_Male']]
y=dataset['Purchased']

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
#https://scikit-learn.org/stable/modules/model_evaluation.html#scoring-parameter

# %%
from sklearn.model_selection import GridSearchCV, cross_val_predict

# ------------------ Random Forest Classifier ------------------
rf_param_grid = {
    'n_estimators': [50, 100, 200],     # number of trees
    'max_depth': [None, 10, 20],        # tree depth
    'criterion': ['gini', 'entropy']    # split measure
}
grid = GridSearchCV(
    estimator=RandomForestClassifier(random_state=42),
    param_grid=rf_param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

# fitting the model for grid search
grid.fit(X,y)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 10, 20],
#                          'n_estimators': [50, 100, 200]},
#              scoring='accuracy')

# %%
# Cross-validated predictions (instead of X_test)
y_pred = cross_val_predict(grid.best_estimator_, X, y, cv=5)

# %%
# Evaluation
from sklearn.metrics import confusion_matrix, classification_report, f1_score
cm = confusion_matrix(y, y_pred)
clf_report = classification_report(y, y_pred)
f1_macro = f1_score(y, y_pred, average='weighted')

# %%
print("Best Parameters:", grid.best_params_)
print("The f1_macro:", f1_macro)
print("The confusion Matrix:\n", cm)
print("The report:\n", clf_report)
# Out:
# Best Parameters: {'criterion': 'gini', 'max_depth': None, 'n_estimators': 200}
# The f1_macro: 0.8545314767655193
# The confusion Matrix:
#  [[230  27]
#  [ 31 112]]
# The report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.89      0.89       257
#            1       0.81      0.78      0.79       143
#
#     accuracy                           0.85       400
#    macro avg       0.84      0.84      0.84       400
# weighted avg       0.85      0.85      0.85       400

# %%
# Save Best Model
import pickle
filename = "RFC_CV_best_model.sav"
pickle.dump(grid.best_estimator_, open(filename, 'wb'))

# %%
# CV Results table
results_df = pd.DataFrame(grid.cv_results_)
results_df.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.146448      0.009168         0.009891        0.000506
# 1       0.296843      0.013519         0.015847        0.001597
# 2       0.550292      0.014107         0.028012        0.000592
# 3       0.143868      0.005164         0.009616        0.000602
# 4       0.288015      0.014940         0.016433        0.000798
#
#   param_criterion param_max_depth  param_n_estimators  \
# 0            gini            None                  50
# 1            gini            None                 100
# 2            gini            None                 200
# 3            gini              10                  50
# 4            gini              10                 100
#
#                                               params  split0_test_score  \
# 0  {'criterion': 'gini', 'max_depth': None, 'n_es...             0.8000
# 1  {'criterion': 'gini', 'max_depth': None, 'n_es...             0.8000
# 2  {'criterion': 'gini', 'max_depth': None, 'n_es...             0.8000
# 3  {'criterion': 'gini', 'max_depth': 10, 'n_esti...             0.7875
# 4  {'criterion': 'gini', 'max_depth': 10, 'n_esti...             0.7875
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0             0.9375             0.8750             0.8375             0.8125
# 1             0.9375             0.8750             0.8375             0.8000
# 2             0.9250             0.8875             0.8375             0.8250
# 3             0.9375             0.8750             0.8375             0.8125
# 4             0.9375             0.8750             0.8375             0.8000
#
#    mean_test_score  std_test_score  rank_test_score
# 0           0.8525        0.049624                3
# 1           0.8500        0.051841                6
# 2           0.8550        0.045139                1
# 3           0.8500        0.052440                6
# 4           0.8475        0.054429               10
